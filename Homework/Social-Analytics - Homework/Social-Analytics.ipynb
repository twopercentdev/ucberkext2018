# %%
# Dependencies
import tweepy
import json
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from datetime import datetime
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
from config import consumer_key, consumer_secret, access_token, access_token_secret

analyzer = SentimentIntensityAnalyzer()

# Setup Tweepy API Authentication
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth, parser=tweepy.parsers.JSONParser())

# %%
# Target User Account
target_user = "@CNN"

# Variables for holding sentiments
cnn_counter = 1
cnn_compound_list = []
cnn_positive_list = []
cnn_negative_list = []
cnn_neutral_list = []
cnn_sentiments = []

# Loop through 5 pages of tweets (total 100 tweets)
for x in range(1, 6):

    # Get all tweets from home feed
    public_tweets = api.user_timeline(target_user, page=x)

    # Loop through all tweets
    for tweet in public_tweets:

        # Run Vader Analysis on each tweet
        cnn_results = analyzer.polarity_scores(tweet["text"])
        compound = cnn_results["compound"]
        pos = cnn_results["pos"]
        neu = cnn_results["neu"]
        neg = cnn_results["neg"]

        # Add each value to the appropriate list
        cnn_compound_list.append(compound)
        cnn_positive_list.append(pos)
        cnn_negative_list.append(neg)
        cnn_neutral_list.append(neu)
        
        cnn_sentiments.append({"Date": tweet["created_at"], 
                           "Compound": compound,
                           "Positive": pos,
                           "Negative": neu,
                           "Neutral": neg,
                           "Tweets Ago": cnn_counter})
        cnn_counter += 1

# %%
cnn_sentiments_pd = pd.DataFrame.from_dict(cnn_sentiments)

x_vals = cnn_sentiments_pd["Tweets Ago"]
y_vals = cnn_sentiments_pd["Compound"]
plt.plot(x_vals,
         y_vals, marker="o", linewidth=0.5,
         alpha=0.8)

## Incorporate the other graph properties
now = datetime.now()
now = now.strftime("%Y-%m-%d %H:%M")
plt.title(f"Sentiment Analysis of Tweets ({now}) for {target_user}")
plt.xlim([x_vals.max(),x_vals.min()])
plt.ylabel("Tweet Polarity")
plt.xlabel("Tweets Ago")
plt.savefig("Images/CNN Sentiment Analysis.png")
plt.show()

# %%
# Target User Account
target_user2 = "@BBC"

# Variables for holding sentiments
bbc_counter = 1
bbc_compound_list = []
bbc_positive_list = []
bbc_negative_list = []
bbc_neutral_list = []
bbc_sentiments = []

# Loop through 5 pages of tweets (total 100 tweets)
for x in range(1, 6):

    # Get all tweets from home feed
    public_tweets = api.user_timeline(target_user2, page=x)

    # Loop through all tweets
    for tweet in public_tweets:

        # Run Vader Analysis on each tweet
        bbc_results = analyzer.polarity_scores(tweet["text"])
        compound = bbc_results["compound"]
        pos = bbc_results["pos"]
        neu = bbc_results["neu"]
        neg = bbc_results["neg"]

        # Add each value to the appropriate list
        bbc_compound_list.append(compound)
        bbc_positive_list.append(pos)
        bbc_negative_list.append(neg)
        bbc_neutral_list.append(neu)
        
        bbc_sentiments.append({"Date": tweet["created_at"], 
                           "Compound": compound,
                           "Positive": pos,
                           "Negative": neu,
                           "Neutral": neg,
                           "Tweets Ago": bbc_counter})
        bbc_counter += 1

# %%
bbc_sentiments_pd = pd.DataFrame.from_dict(bbc_sentiments)

x_vals = bbc_sentiments_pd["Tweets Ago"]
y_vals = bbc_sentiments_pd["Compound"]
plt.plot(x_vals,
         y_vals, marker="o", linewidth=0.5,
         alpha=0.8)

## Incorporate the other graph properties
now = datetime.now()
now = now.strftime("%Y-%m-%d %H:%M")
plt.title(f"Sentiment Analysis of Tweets ({now}) for {target_user2}")
plt.xlim([x_vals.max(),x_vals.min()])
plt.ylabel("Tweet Polarity")
plt.xlabel("Tweets Ago")
plt.savefig("Images/BBC Sentiment Analysis.png")
plt.show()

# %%
# Target User Account
target_user3 = "@CBS"

# Variables for holding sentiments
cbs_counter = 1
cbs_compound_list = []
cbs_positive_list = []
cbs_negative_list = []
cbs_neutral_list = []
cbs_sentiments = []

# Loop through 5 pages of tweets (total 100 tweets)
for x in range(1, 6):

    # Get all tweets from home feed
    public_tweets = api.user_timeline(target_user3, page=x)

    # Loop through all tweets
    for tweet in public_tweets:

        # Run Vader Analysis on each tweet
        cbs_results = analyzer.polarity_scores(tweet["text"])
        compound = cbs_results["compound"]
        pos = cbs_results["pos"]
        neu = cbs_results["neu"]
        neg = cbs_results["neg"]

        # Add each value to the appropriate list
        cbs_compound_list.append(compound)
        cbs_positive_list.append(pos)
        cbs_negative_list.append(neg)
        cbs_neutral_list.append(neu)
        
        cbs_sentiments.append({"Date": tweet["created_at"], 
                    "Compound": compound,
                    "Positive": pos,
                    "Negative": neu,
                    "Neutral": neg,
                    "Tweets Ago": cbs_counter})
        cbs_counter += 1

# %%
cbs_sentiments_pd = pd.DataFrame.from_dict(cbs_sentiments)

x_vals = cbs_sentiments_pd["Tweets Ago"]
y_vals = cbs_sentiments_pd["Compound"]
plt.plot(x_vals,
         y_vals, marker="o", linewidth=0.5,
         alpha=0.8)

## Incorporate the other graph properties
now = datetime.now()
now = now.strftime("%Y-%m-%d %H:%M")
plt.title(f"Sentiment Analysis of Tweets ({now}) for {target_user3}")
plt.xlim([x_vals.max(),x_vals.min()])
plt.ylabel("Tweet Polarity")
plt.xlabel("Tweets Ago")
plt.savefig("../Images/CBS Times Sentiment Analysis.png")
plt.show()

# %%
# Target User Account
target_user4 = "@FoxNews"

# Variables for holding sentiments
fxn_counter = 1
fxn_compound_list = []
fxn_positive_list = []
fxn_negative_list = []
fxn_neutral_list = []
fxn_sentiments = []

# Loop through 5 pages of tweets (total 100 tweets)
for x in range(1, 6):

    # Get all tweets from home feed
    public_tweets = api.user_timeline(target_user4, page=x)

    # Loop through all tweets
    for tweet in public_tweets:

        # Run Vader Analysis on each tweet
        fxn_results = analyzer.polarity_scores(tweet["text"])
        compound = fxn_results["compound"]
        pos = fxn_results["pos"]
        neu = fxn_results["neu"]
        neg = fxn_results["neg"]

        # Add each value to the appropriate list
        fxn_compound_list.append(compound)
        fxn_positive_list.append(pos)
        fxn_negative_list.append(neg)
        fxn_neutral_list.append(neu)
        
        fxn_sentiments.append({"Date": tweet["created_at"], 
                    "Compound": compound,
                    "Positive": pos,
                    "Negative": neu,
                    "Neutral": neg,
                    "Tweets Ago": fxn_counter})
        fxn_counter += 1

# %%
fxn_sentiments_pd = pd.DataFrame.from_dict(fxn_sentiments)

x_vals = fxn_sentiments_pd["Tweets Ago"]
y_vals = fxn_sentiments_pd["Compound"]
plt.plot(x_vals,
         y_vals, marker="o", linewidth=0.5,
         alpha=0.8)

## Incorporate the other graph properties
now = datetime.now()
now = now.strftime("%Y-%m-%d %H:%M")
plt.title(f"Sentiment Analysis of Tweets ({now}) for {target_user4}")
plt.xlim([x_vals.max(),x_vals.min()])
plt.ylabel("Tweet Polarity")
plt.xlabel("Tweets Ago")
plt.savefig("../Images/Fox News Sentiment Analysis.png")
plt.show()

# %%
# Target User Account
target_user5 = "@Nytimes"

# Variables for holding sentiments
nyt_counter = 1
nyt_compound_list = []
nyt_positive_list = []
nyt_negative_list = []
nyt_neutral_list = []
nyt_sentiments = []

# Loop through 5 pages of tweets (total 100 tweets)
for x in range(1, 6):

    # Get all tweets from home feed
    public_tweets = api.user_timeline(target_user5, page=x)

    # Loop through all tweets
    for tweet in public_tweets:

        # Run Vader Analysis on each tweet
        nyt_results = analyzer.polarity_scores(tweet["text"])
        compound = nyt_results["compound"]
        pos = nyt_results["pos"]
        neu = nyt_results["neu"]
        neg = nyt_results["neg"]

        # Add each value to the appropriate list
        nyt_compound_list.append(compound)
        nyt_positive_list.append(pos)
        nyt_negative_list.append(neg)
        nyt_neutral_list.append(neu)
        
        nyt_sentiments.append({"Date": tweet["created_at"], 
                    "Compound": compound,
                    "Positive": pos,
                    "Negative": neu,
                    "Neutral": neg,
                    "Tweets Ago": nyt_counter})
        nyt_counter += 1

# %%
nyt_sentiments_pd = pd.DataFrame.from_dict(nyt_sentiments)

x_vals = nyt_sentiments_pd["Tweets Ago"]
y_vals = nyt_sentiments_pd["Compound"]
plt.plot(x_vals,
         y_vals, marker="o", linewidth=0.5,
         alpha=0.8)

## Incorporate the other graph properties
now = datetime.now()
now = now.strftime("%Y-%m-%d %H:%M")
plt.title(f"Sentiment Analysis of Tweets ({now}) for {target_user5}")
plt.xlim([x_vals.max(),x_vals.min()])
plt.ylabel("Tweet Polarity")
plt.xlabel("Tweets Ago")
plt.savefig("../Images/New York Times Sentiment Analysis.png")
plt.show()

# %%
aggregated_compound = {(target_user) : (np.mean(cnn_compound_list)),
                       (target_user2) : np.mean(bbc_compound_list),
                       (target_user3) : np.mean(cbs_compound_list),
                       (target_user4) : np.mean(fxn_compound_list),
                       (target_user5) : np.mean(nyt_compound_list)}

aggregated_compound_pd = pd.Series(aggregated_compound)

# %%
len(aggregated_compound_pd.index)
plt.bar(range(len(aggregated_compound_pd.index)), aggregated_compound_pd.values)
plt.xticks(range(len(aggregated_compound_pd.index)), aggregated_compound_pd.index, rotation=45)
plt.ylabel("Average Compound Sentiment")
plt.xlabel("News Station Name")
plt.title("Sentiment based on most recent 100 tweets from various news stations")
plt.savefig("../Images/News Groups Compound Sentiment.png")
plt.show()

# %%
nyt_sentiments_pd.to_csv('New York Times Sentiments.csv', index = False, header = True)
cnn_sentiments_pd.to_csv('CNN Sentiments.csv', index = False, header = True)
cbs_sentiments_pd.to_csv('CBS Sentiments.csv', index = False, header = True)
bbc_sentiments_pd.to_csv('BBC Sentiments.csv', index = False, header = True)
fxn_sentiments_pd.to_csv('Fox News Sentiments.csv', index = False, header = True)
